# %% [markdown]
# # Deals Part 2: The Power of SQL `SELECT`s

# %% [markdown]
# *This notebook uses SQL select statements to learn about mergers and acquisitions in the 1990s. No, actually it's just all about SELECT statements.*

# %% [markdown]
# ## Library Imports & Database Connection
# Some version of the following will need to appear near the top of every notebook in this course. It imports the necessary software libraries and connects to a database

# %%
# All query results are returned as Pandas DataFrames 
import pandas as pd

# Needed for %sql Magic
# %load_ext sql

# use %sql magic to connect to the deals database
# %sql mysql+pymysql://dealsuser:deals@database-01202.c55qjoeogr2p.us-east-2.rds.amazonaws.com/deals
# Out:
# 'Connected: dealsuser@deals'

# %% [markdown]
# Let's review, line by line:
# - The code above is actually Python, which is what Jupyter prefers to use natively.
# - The lines that start with `#` are comments with English text explaining what the line below is about.
# - The `import` line allows us to use the pandas library that is all the rage at data science parties. pandas -- note that the p is is never capitalized -- provides data structures that emulate database tables. We won't make use of it here but it may be useful in later assignments.
# - The `%load_ext` statement extends Jupyter to allow SQL statements instead of Python. Any statement that starts with %sql or %%sql is run as SQL instead of Python. For details of how this works, RTFM at the [ipython-sql](https://github.com/catherinedevlin/ipython-sql) repo on GitHub.
# - The last line uses `%sql` to connect to an online MySQL database. The pseudo-URL at the end (complete with `://` in the middle) tells Jupyter
#     i) how to connect (i.e., using the pymysql bridge),
#     ii) what kind of database server is on the other end of the connection (i.e., mysql),
#     iii) who is connecting (i.e., login with user `dealsuser` and password `deals`), and
#     iv) where to connect to (i.e., a databse called `deals` hosted on the local [same] computer as Jupyter).

# %% [markdown]
# ## A Brief Warmup
# To make sure that everything is working correctly, let's try a basic `SELECT` query. Copy the following into the code cell below.
#
# ```SQL
# %%sql
# /* Indicate that we are using the deals database */
# USE deals;
# /* Execute a test query  */
# SELECT *
# FROM Companies
# WHERE CompanyName like "%Inc."
# ```
# A few notes:
# - `%%sql` magic allows us to split SQL statements onto multiple lines.
# - `US`E indicates what database to use, which is useful when there are multiple database connections (e.g., when copying data from one database to another).
# - SQL comments use `/*  */` format.
# - The `SELECT` statement is broken out into multiple clauses, each with a different purpose. The last clause (`WHERE CompanyName like "%Inc."`) restricts the listing to only companies with "Inc." at the end of their names.
# - The table names are case sensitive! If we were to use `COMPANIES` instead of `Companies` then the query breaks. Try it yourself! (Why the nonstandard name? When this database was first created in 1998, it was distributed as an MS Access database, which always followed CamelCase for table names.)

# %%
# %%sql
# /* Indicate that we are using the deals database */
# USE deals;
# /* Execute a test query  */
# SELECT *
# FROM Companies
# WHERE CompanyName like "%Inc."
# Out:
#  * mysql+pymysql://dealsuser:***@database-01202.c55qjoeogr2p.us-east-2.rds.amazonaws.com/deals
# 0 rows affected.
# 111 rows affected.
# [(2, 'Abitibi-Price Inc.'),
#  (5, 'AirTouch Communications, Inc.'),
#  (6, 'Alex. Brown Inc.'),
#  (7, 'Allegheny Power System Inc.'),
#  (318, 'American Bankers Insurance Group Inc.'),
#  (319, 'American International Group Inc.'),
#  (11, 'American Medical Response, Inc.'),
#  (13, 'American Standard Companies, Inc.'),
#  (19, 'Apria Healthcare Group Inc.'),
#  (20, 'Ascend Communications, Inc.'),
#  (25, 'Barnett Banks, Inc.'),
#  (314, 'BDM International Inc.'),
#  (311, 'Beckman Instruments, Inc.'),
#  (31, 'Brooks Fiber Properties, Inc.'),
#  (33, 'Burlington Resources Inc.'),
#  (35, 'Calilber Systems Inc.'),
#  (37, 'Cardinal Health, Inc.'),
#  (303, 'Caterpillar Inc.'),
#  (41, 'Central Fidelity Banks Inc.'),
#  (42, 'Century Telephone Enterprises Inc.'),
#  (279, 'Ciba Specialty Chemicals Inc.'),
#  (50, 'Clear Channel Communications, Inc.'),
#  (52, 'Coca-Cola Enterprises Inc.'),
#  (64, 'CUC International Inc.'),
#  (68, 'Destec Energy, Inc.'),
#  (70, 'DowBrands Inc.'),
#  (71, 'DQE Inc.'),
#  (79, 'Evans Withycombe Residential Inc.'),
#  (81, 'Excel Communications, Inc.'),
#  (85, 'First Bank System, Inc.'),
#  (89, 'First USA, Inc.'),
#  (90, 'Fisher Scientific International Inc.'),
#  (91, 'Fleet Financial Group, Inc.'),
#  (93, 'Fox Kids Worldwide Inc.'),
#  (94, 'Fred Meyer Inc.'),
#  (96, 'GPU, Inc.'),
#  (97, 'GranCare Inc.'),
#  (99, 'Greenfield Industries, Inc.'),
#  (102, 'Healthsource, Inc.'),
#  (278, 'Hercules Inc.'),
#  (108, 'HFS Inc.'),
#  (109, 'Hicks, Muse, Tate & Furst Inc.'),
#  (112, 'Homeside, Inc.'),
#  (114, 'Household International Inc.'),
#  (115, 'HSN Inc.'),
#  (122, 'Integrated Health Services Inc.'),
#  (123, 'International Family Entertainment Inc.'),
#  (126, 'Investor Group led by Transworld Healthcare Inc.'),
#  (130, 'JP Foodservice Inc.'),
#  (131, 'Kennametal Inc.'),
#  (132, 'Keystone International Inc.'),
#  (138, 'Laidlaw Environmental Services, Inc.'),
#  (140, 'Laidlaw Inc.'),
#  (145, 'Living Centers of America Inc.'),
#  (150, 'Lucent Technologies Inc.'),
#  (151, "Mac Frugal's Bargains & Close-Outs Inc."),
#  (152, 'Mallinckrodt Inc.'),
#  (300, 'Mapco Inc.'),
#  (153, 'Marriott International, Inc.'),
#  (154, 'Marsh & McLennan Companies, Inc.'),
#  (155, 'McAfee Associates Inc.'),
#  (156, 'McClatchy Newspapers, Inc.'),
#  (159, 'MedPartners, Inc.'),
#  (162, 'MESA, Inc.'),
#  (163, 'Monterey Resources Inc.'),
#  (165, 'Morgan Stanley Group Inc.'),
#  (170, 'Nellcor Puritan Bennett Inc.'),
#  (317, 'Newcourt Credit Group Inc.'),
#  (282, 'Ocean Energy Inc.'),
#  (177, 'Outdoor Systems Inc.'),
#  (178, 'Overseas Shipholding Group, Inc.'),
#  (179, 'Pacific Telecom Inc.'),
#  (183, 'Patriot American Hospitality Inc.'),
#  (187, 'PhyCor Inc.'),
#  (194, 'Quality Food Centers Inc.'),
#  (197, 'Raycom Media, Inc.'),
#  (296, 'Renal Treatment Centers Inc.'),
#  (202, 'Revco D.S., Inc.'),
#  (204, 'Rohr Inc.'),
#  (205, 'Rollins Environmental Services, Inc.'),
#  (207, 'Rykoff Sexton Inc.'),
#  (208, 'S.C. Johnson & Son Inc.'),
#  (211, 'Salomon Inc.'),
#  (213, 'Scudder, Stevens & Clark Inc.'),
#  (217, 'SFX Broadcasting Inc.'),
#  (289, 'Showboat Inc.'),
#  (294, 'Simon DeBartolo Group Inc.'),
#  (280, 'Sonat Inc.'),
#  (226, 'Tambrands Inc.'),
#  (227, 'Tandem Computers Inc.'),
#  (228, 'Target Therapeutics, Inc.'),
#  (231, 'Telco Communications Group Inc.'),
#  (232, 'Tele-Communications, Inc.'),
#  (233, 'Tencor Instruments Inc.'),
#  (234, 'Texaco Inc.'),
#  (297, 'Total Renal Care Holdings Inc.'),
#  (315, 'TRW Inc.'),
#  (246, 'U.S. West, Inc.'),
#  (247, 'Union Pacific Resources Group Inc.'),
#  (248, 'United Waste Systems, Inc.'),
#  (249, 'Universal Outdoor Holdings Inc.'),
#  (250, 'Universal Studios, Inc.'),
#  (252, 'USA Waste Services Inc.'),
#  (255, 'Value Health, Inc.'),
#  (256, 'Vencor, Inc.'),
#  (257, 'Verifone, Inc.'),
#  (259, 'Vivra Inc.'),
#  (261, 'Wal-Mart Stores, Inc.'),
#  (262, 'Washington Mutual Inc.'),
#  (264, 'Western Resources, Inc.'),
#  (268, 'WorldCom, Inc.')]

# %% [markdown]
# ## Your First Bug
# Run the code below, which has two SQL statements in a row. It has a bug, as indicated by a cryptic error message:
# > (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'SELECT *\nFROM Companies\nORDER BY CompanyID' at line 7")
#
# What does `Error Code: 1064` mean? It's a syntax error. Can you spot the bug in the code? In this case it's pretty subtle: we are missing a semi-colon (`;`) at the end of each SELECT statement. Add the missing semi-colons and rerun. It should work now (though only the results of the second query will be shown; it's a Jupyter thing).

# %%
# %%sql
# /* Select companies whose names end with Inc. */
# SELECT *
# FROM Companies
# WHERE CompanyName like "%Inc.";
#
# /* Select companies sorted by CompanyName */
# SELECT *
# FROM Companies
# ORDER BY CompanyID
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@database-01202.c55qjoeogr2p.us-east-2.rds.amazonaws.com/deals
# 111 rows affected.
# 10 rows affected.
# [(1, '3Com Corporation'),
#  (2, 'Abitibi-Price Inc.'),
#  (3, 'ADT Limited'),
#  (4, 'Advanta Corp. Credit card unit'),
#  (5, 'AirTouch Communications, Inc.'),
#  (6, 'Alex. Brown Inc.'),
#  (7, 'Allegheny Power System Inc.'),
#  (8, 'Allied Irish Banks P.L.C.'),
#  (9, 'American Electric Power Co. Inc. and Public Service'),
#  (10, 'American General Corp.')]

# %% [markdown]
# ## Your First Join
# Now let's add another query, this time with data from two tables: `Deals` and `DealParts`.

# %%
# %%sql
# SELECT DealName,PartNumber,DollarValue
# FROM Deals, DealParts
# WHERE Deals.DealID = DealParts.DealID
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@database-01202.c55qjoeogr2p.us-east-2.rds.amazonaws.com/deals
# 10 rows affected.
# [('ADT Limited', 1, Decimal('5600.0000')),
#  ('Advanta Corp.', 1, Decimal('1300.0000')),
#  ('Alex. Brown Inc.', 1, Decimal('1700.0000')),
#  ('Allied Colloids Group PLC', 1, Decimal('1810.0000')),
#  ('American First Financial Insurance Group Inc.', 1, Decimal('2200.0000')),
#  ('American Medical Response, Inc.', 1, Decimal('1120.0000')),
#  ('American Radio Systems Corp.', 1, Decimal('2600.0000')),
#  ('American Standard Companies, Inc.', 1, Decimal('4000.0000')),
#  ('Amerisource Health Corp.', 1, Decimal('2322.0000')),
#  ('Amphenol Corp.', 1, Decimal('1500.0000'))]

# %% [markdown]
# Here we used the `WHERE` clause to indicate that the `DealID` on the `Deals` table has to match the `DealID` on the `DealParts` table. Believe it or not, that basic logic (that keys on one table have t match keys on anther table) is exactly 92% of the power of the Relational Database Model. We can now just end the course now. How about the final exam next week?

# %% [markdown]
# More seriously, while using the `WHERE` clause to match records from different tables works, it s not very efficient. Instead we will want to use a `JOIN .. USING` operator, which is optimized to work with millions of records without breaking a sweat. In this case we don't even need a WHERE clause!

# %%
# %%sql
# SELECT DealName,PartNumber,DollarValue
# FROM Deals
#      JOIN DealParts USING (DealID)
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@database-01202.c55qjoeogr2p.us-east-2.rds.amazonaws.com/deals
# 10 rows affected.
# [('ADT Limited', 1, Decimal('5600.0000')),
#  ('Advanta Corp.', 1, Decimal('1300.0000')),
#  ('Alex. Brown Inc.', 1, Decimal('1700.0000')),
#  ('Allied Colloids Group PLC', 1, Decimal('1810.0000')),
#  ('American First Financial Insurance Group Inc.', 1, Decimal('2200.0000')),
#  ('American Medical Response, Inc.', 1, Decimal('1120.0000')),
#  ('American Radio Systems Corp.', 1, Decimal('2600.0000')),
#  ('American Standard Companies, Inc.', 1, Decimal('4000.0000')),
#  ('Amerisource Health Corp.', 1, Decimal('2322.0000')),
#  ('Amphenol Corp.', 1, Decimal('1500.0000'))]

# %% [markdown]
# We can actually 'chain' table joins to link in data from as many tables as we want. We just have to specify what columns to use as keys! Each join in the chain creates a virtual table onto which we can join another table.

# %%
# %%sql
# SELECT DealName,LongCode as Role,CompanyName
# FROM Companies
#     JOIN Players USING (CompanyID)
#     JOIN RoleCodes USING (RoleCode)
#     JOIN Deals USING (DealID)
# ORDER BY DealName
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@database-01202.c55qjoeogr2p.us-east-2.rds.amazonaws.com/deals
# 10 rows affected.
# [('ADT Limited', 'Target', 'ADT Limited'),
#  ('ADT Limited', 'Second Bidder', 'Tyco International Ltd.'),
#  ('ADT Limited', 'First Bidder', 'Western Resources, Inc.'),
#  ('Advanta Corp.', 'Acquiror', 'Fleet Financial Group, Inc.'),
#  ('Advanta Corp.', 'Target', 'Advanta Corp. Credit card unit'),
#  ('Alex. Brown Inc.', 'Target', 'Alex. Brown Inc.'),
#  ('Alex. Brown Inc.', 'Acquiror', 'Bankers Trust New York Corporation'),
#  ('Allied Colloids Group PLC', 'First Bidder', 'Hercules Inc.'),
#  ('Allied Colloids Group PLC', 'Target', 'Allied Colloids Group'),
#  ('American First Financial Insurance Group Inc.', 'Acquiror', 'American International Group Inc.')]

# %% [markdown]
# Study the database schema below to see more opportunities to join tables. You will use this as a guide in the queries that follow.
#  ![Deals ERD](img/img2_7.png)

# %% [markdown]
# ## Challenge Queries: Now for the Fun Stuff
# Three queries are described below. In the code cell provided after each description, write a SQL query that best answers the question. Each query should answer the question completely, without us humans needing to do any sorting, counting, etc.
#
# Don't forget to start each query cell with `%%sql`.
#
# It's okay to collaborate with your classmates. Just be sure that you are typing out your own code.

# %% [markdown]
# ### Query 1: Lots of joins
# **For each deal, list every firm involved, what supporting role it played, and which company it supported.**
# You will need to output the following fields:
# - `DealName` from the `Deals` table
# - `Name` from the `Firms` table
# - `LongCode` from the `SupportCodes` table
# - `CompanyName` from the `Companies` table
#
# You will also need to use keys from the `Players` and `PlayerSupport` tables.

# %%
# %%sql
# SELECT DealName, Name, LongCode, CompanyName
# FROM Deals
#     JOIN Players USING (DealID)
#     JOIN PlayerSupports USING (PlayerID)
#     JOIN Firms USING (FirmID)
#     JOIN SupportCodes USING (SupportCodeID)
#     JOIN Companies USING (CompanyID)
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@database-01202.c55qjoeogr2p.us-east-2.rds.amazonaws.com/deals
# 10 rows affected.
# [('Alex. Brown Inc.', 'BT Wolfensohn', 'Investment Adviser', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'Debevoise & Plimpton', 'Counsel', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'Kissel-Blake Inc.', 'Proxy Solicitor', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Bankers Trust New York Corporation'),
#  ('American Medical Response, Inc.', 'Katten Muchin & Zavis', 'Outside Counsel', 'Laidlaw Inc.'),
#  ('American Medical Response, Inc.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Laidlaw Inc.'),
#  ('American Medical Response, Inc.', 'Simpson Thacher & Bartlett', 'Counsel', 'Laidlaw Inc.'),
#  ('Amphenol Corp.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'Investment Adviser', 'Kohlberg Kravis Roberts & Co.'),
#  ('Amphenol Corp.', 'Kekst and Company', 'Public Relations Firm', 'Kohlberg Kravis Roberts & Co.'),
#  ('Amphenol Corp.', 'MacKenzie Partners, Inc.', 'Proxy Solicitor', 'Kohlberg Kravis Roberts & Co.')]

# %% [markdown]
# ### Query 2: Aggregation
# **List the DealID, total dollar value and number of parts for each deal.**
# Don't forget to use your database schema map when planning out your joins. Also, be sure to include a comment (above the code) indicating what the view is intended to do.

# %%
# %%sql
# SELECT DealID, ROUND(SUM(DollarValue),2) AS TotalValue, COUNT(PartNumber) AS NumParts
# FROM DealParts
# GROUP BY DealID
# HAVING NumParts>1;
# Out:
#  * mysql+pymysql://dealsuser:***@database-01202.c55qjoeogr2p.us-east-2.rds.amazonaws.com/deals
# 6 rows affected.
# [(62, Decimal('2625.00'), 2),
#  (103, Decimal('78880.00'), 3),
#  (117, Decimal('3000.00'), 2),
#  (122, Decimal('19500.00'), 2),
#  (123, Decimal('3900.00'), 2),
#  (141, Decimal('2640.00'), 2)]

# %% [markdown]
# ### Query 3: Even More Aggregation
# **List the DealID, DealName, number of players, total dollar value, and number of parts for each deal.**
# Bonus: use a subquery to construct a comma-separated list of deal types for each deal. (Don't forget the explanatory comment.)

# %%
# %%sql
# SELECT DealID,
#         DealName,
#         COUNT(PlayerID) AS NumPlayers,
#         ROUND(SUM(DollarValue),2) AS TotalValue,
#         COUNT(PartNumber) AS NumParts
# FROM Deals
#     JOIN Players USING (DealID)
#     JOIN DealParts USING (DealID)
# GROUP BY DealID
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@database-01202.c55qjoeogr2p.us-east-2.rds.amazonaws.com/deals
# 10 rows affected.
# [(1, 'ADT Limited', 3, Decimal('16800.00'), 3),
#  (2, 'Alex. Brown Inc.', 2, Decimal('3400.00'), 2),
#  (3, 'American Medical Response, Inc.', 2, Decimal('2240.00'), 2),
#  (4, 'American Standard Companies, Inc.', 2, Decimal('8000.00'), 2),
#  (5, 'Amphenol Corp.', 2, Decimal('3000.00'), 2),
#  (6, 'Bankamerica Corp.', 1, Decimal('1600.00'), 1),
#  (7, 'Berliner Kraft & Licht AG', 1, Decimal('1870.00'), 1),
#  (8, 'Cascade Communications Corp.', 2, Decimal('7400.00'), 2),
#  (9, 'Chancellor Broadcasting Comp.', 2, Decimal('3200.00'), 2),
#  (10, 'Cifra S.A.', 2, Decimal('2400.00'), 2)]

# %% [markdown]
# ### Query 4: A Surprisingly Tricky One
# **List TypeCode, number of deals, and total value of deals for each deal type.**
# Each firm should be listed, even if there are no deals for that firm.

# %%
# %%sql
# SELECT TypeCode,
#         COUNT(DealID) AS NumDeals,
#         ROUND(SUM(DollarValue),2) AS TotalValue
# FROM TypeCodes
#     JOIN DealTypes USING (TypeCode)
#     JOIN Deals USING (DealID)
#     JOIN DealParts USING (DealID)
# GROUP BY TypeCode;
# Out:
#  * mysql+pymysql://dealsuser:***@database-01202.c55qjoeogr2p.us-east-2.rds.amazonaws.com/deals
# 6 rows affected.
# [('C/S', 80, Decimal('271794.00')),
#  ('CM', 3, Decimal('8030.00')),
#  ('PA', 1, Decimal('1880.00')),
#  ('PF', 4, Decimal('27790.00')),
#  ('SS', 59, Decimal('204658.00')),
#  ('TO', 16, Decimal('55972.00'))]

# %% [markdown]
# ### Query 5: Make up your own query to share.
# Be creative. Impress us with your brilliance!

# %%
# %%sql
# SELECT DealName,
#         Name AS Firm,
#         CompanyName,
#         COUNT(PartNumber) AS NumParts,
#         TypeCode,
#         LongCode,
#         ROUND(SUM(DollarValue),2) AS TotalValue
# FROM Deals
#     JOIN DealTypes USING (DealID)
#     JOIN Players USING (DealID)
#     JOIN PlayerSupports USING (PlayerID)
#     JOIN Firms USING (FirmID)
#     JOIN TypeCodes USING (TypeCode)
#     JOIN DealParts USING (DealID)
#     JOIN RoleCodes USING (RoleCode)
#     JOIN Companies USING (CompanyID)
# GROUP BY DealID
# ORDER BY TotalValue DESC;
# Out:
#  * mysql+pymysql://dealsuser:***@database-01202.c55qjoeogr2p.us-east-2.rds.amazonaws.com/deals
# 148 rows affected.
# [('MCI Communications Corporation', 'Burson-Marsteller', 'British Telecommunications PLC', 90, 'C/S', 'First Bidder', Decimal('2366400.00')),
#  ('ITT Corp.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'Hilton Hotels Corp.', 92, 'PF', 'First Bidder', Decimal('897000.00')),
#  ('Great Western Financial Corp.', 'Credit Suisse First Boston', 'H.F. Ahmanson & Co.', 38, 'PF', 'First Bidder', Decimal('250420.00')),
#  ('ADT Limited', 'Bear, Stearns & Co., Inc.', 'Western Resources, Inc.', 38, 'SS', 'First Bidder', Decimal('212800.00')),
#  ('General Motors Corp.', 'Bear, Stearns & Co., Inc.', 'Raytheon Company', 18, 'SS', 'Acquiror', Decimal('171000.00')),
#  ('Barnett Banks, Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'NationsBank Corporation', 11, 'SS', 'Acquiror', Decimal('170500.00')),
#  ('Corestates Financial Corp.', 'Alston & Bird', 'First Union Corporation', 9, 'C/S', 'Acquiror', Decimal('162000.00')),
#  ('Morgan Stanley Group Inc.', 'Cravath, Swaine & Moore', 'Dean Witter Discover & Co.', 12, 'SS', 'Acquiror', Decimal('126000.00')),
#  ('Pennzoil Comp.', 'Dewey Ballantine', 'Union Pacific Resources Group Inc.', 19, 'TO', 'Acquiror', Decimal('117800.00')),
#  ('U.S. Bancorp', 'Cleary, Gottlieb, Steen & Hamilton', 'First Bank System, Inc.', 13, 'SS', 'Merger Partner', Decimal('117000.00')),
#  ('The Energy Group PLC', 'Goldman, Sachs & Co.', 'PacifiCorp', 11, 'C/S', 'Acquiror', Decimal('106700.00')),
#  ('HFS Inc.', 'D.F. King & Co., Inc.', 'CUC International Inc.', 9, 'SS', 'Acquiror', Decimal('98100.00')),
#  ('Lin Television Corp.', 'Davis Polk & Wardell', 'Hicks, Muse, Tate & Furst Inc. and NBC', 34, 'C/S', 'Acquiror', Decimal('66300.00')),
#  ('Northrop Grumman Corp.', 'Bear, Stearns & Co., Inc.', 'Lockheed Martin Corp.', 8, 'C/S', 'Acquiror', Decimal('66080.00')),
#  ('Central & South West Corp.', 'Vinson & Elkins', 'Central & South West Corp.', 10, 'SS', 'Target', Decimal('66000.00')),
#  ('First USA, Inc.', 'Lazard Freres & Co. LLC', 'Banc One Corporation', 9, 'SS', 'Acquiror', Decimal('63000.00')),
#  ('U.S. Robotics Corp.', 'Goldman, Sachs & Co.', '3Com Corporation', 8, 'SS', 'Acquiror', Decimal('58400.00')),
#  ('Medpartners, Inc.', 'Alston & Bird', 'PhyCor Inc.', 7, 'SS', 'Acquiror', Decimal('57260.00')),
#  ('The Unilever Group', 'Davis Polk & Wardell', 'Imperial Chemical Industries PLC', 7, 'C/S', 'Acquiror', Decimal('56000.00')),
#  ('Revco D.S., Inc.', 'Dewey Ballantine', 'CVS Corporation', 15, 'SS', 'Acquiror', Decimal('55500.00')),
#  ('Coopers & Lybrand L.L.P.', 'Cravath, Swaine & Moore', 'Price Waterhouse', 4, 'C/S', 'Merger Partner', Decimal('48000.00')),
#  ('First of America Bank Corp.', 'Wachtell, Lipton, Rosen & Katz', 'First of America Bank Corp.', 7, 'C/S', 'Target', Decimal('47600.00')),
#  ('Read-Rite Corp.', 'Chadbourne & Parke', 'Applied Magnetics Corp.', 24, 'PF', 'Acquiror', Decimal('40800.00')),
#  ('Salomon Inc.', 'Kekst and Company', 'Travelers Group', 4, 'SS', 'Acquiror', Decimal('36000.00')),
#  ('U.S. West, Inc.', 'Morgan Stanley & Co. Inc.', 'AirTouch Communications, Inc.', 7, 'SS', 'Acquiror', Decimal('35000.00')),
#  ('W.R. Grace & Comp.', 'Chadbourne & Parke', 'Sealed Air Corporation', 7, 'SS', 'Acquiror', Decimal('34300.00')),
#  ('Ralphs Grocery Company', 'Morgan, Lewis & Bockius', 'Apollo Advisors', 11, 'SS', 'Shareholder', Decimal('34100.00')),
#  ('The Louisiana Land and Exploration Company', 'D.F. King & Co., Inc.', 'Burlington Resources Inc.', 11, 'SS', 'Acquiror', Decimal('33000.00')),
#  ('Tejas Gas Corp.', 'Cravath, Swaine & Moore', 'Shell Oil Company', 14, 'C/S', 'Acquiror', Decimal('32900.00')),
#  ('Seagram Company', 'Wachtell, Lipton, Rosen & Katz', 'HSN Inc.', 8, 'C/S', 'Acquiror', Decimal('32800.00')),
#  ('American Standard Companies, Inc.', 'Credit Suisse First Boston', 'Tyco International Ltd.', 8, 'C/S', 'Bidder', Decimal('32000.00')),
#  ('Mercury Asset Management Group, P.L.C.', 'Davis Polk & Wardell', 'Mercury Asset Management Group, P.L.C.', 6, 'CM', 'Target', Decimal('31800.00')),
#  ('American Radio Systems Corp.', 'Chase Securities Inc.', 'Westinghouse Electric Corp.', 12, 'C/S', 'Acquiror', Decimal('31200.00')),
#  ('Tandem Computers Inc.', 'Davis Polk & Wardell', 'Compaq Computer Corp.', 10, 'SS', 'Acquiror', Decimal('30000.00')),
#  ('Cascade Communications Corp.', 'Deutsche Morgan Grenfell', 'Ascend Communications, Inc.', 8, 'SS', 'Acquiror', Decimal('29600.00')),
#  ('DQE Inc.', 'Merrill Lynch & Co.', 'Allegheny Power System Inc.', 7, 'C/S', 'Acquiror', Decimal('29470.00')),
#  ('Safety-Kleen Corp.', 'Innisfree M&A Inc.', 'Laidlaw Environmental Services, Inc.', 16, 'TO', 'Acquiror', Decimal('28800.00')),
#  ('International Family Entertainment Inc.', 'Potter Anderson & Corroon', 'Fox Kids Worldwide Inc.', 15, 'C/S', 'Acquiror', Decimal('28500.00')),
#  ('Lincoln National Corporation', 'Broadgate Consultants', 'Safeco Corporation', 10, 'C/S', 'Acquiror', Decimal('28200.00')),
#  ('Yorkshire Electricity', 'Allen & Overy', 'American Electric Power Co. Inc. and Public Service', 10, 'TO', 'Acquiror', Decimal('28000.00')),
#  ('Beacon Properties Corp.', 'J.P. Morgan & Co., Inc.', 'Equity Office Properties Trust', 7, 'SS', 'Acquiror', Decimal('28000.00')),
#  ('Bergen Brunswig Corp.', 'Dewey Ballantine', 'Cardinal Health, Inc.', 11, 'SS', 'Acquiror', Decimal('27500.00')),
#  ('Fort Howard Corp.', 'Burson-Marsteller', 'James River Corp.', 8, 'SS', 'Acquiror', Decimal('27200.00')),
#  ('Ernst & Young LLP', 'Weil, Gotshal & Manges', 'KPMG Peat Marwick LLP', 2, 'C/S', 'Merger Partner', Decimal('26000.00')),
#  ('Tambrands Inc.', 'Cleary, Gottlieb, Steen & Hamilton', 'Procter & Gamble Co.', 13, 'C/S', 'Acquiror', Decimal('26000.00')),
#  ('Renaissance Hotel Group N.V.', 'Gibson, Dunn & Crutcher', 'Marriott International, Inc.', 24, 'C/S', 'Second Bidder', Decimal('24000.00')),
#  ('New York State Electric & Gas Corp.', 'Credit Suisse First Boston', 'CalEnergy Co.', 12, 'TO', 'Acquiror', Decimal('23040.00')),
#  ('Interstate Hotel Company', 'Jones, Day, Reavis & Pogue', 'Interstate Hotels Company', 16, 'C/S', 'Target', Decimal('21120.00')),
#  ('Rykoff Sexton Inc.', 'Dewey Ballantine', 'JP Foodservice Inc.', 15, 'SS', 'Acquiror', Decimal('20835.00')),
#  ('MAPCO Inc.', 'Debevoise & Plimpton', 'Mapco Inc.', 6, 'SS', 'Target', Decimal('20760.00')),
#  ('Texas Instruments Inc.', 'Bear, Stearns & Co., Inc.', 'Raytheon Company', 7, 'C/S', 'Acquiror', Decimal('20650.00')),
#  ('Calilber Systems Inc.', 'Davis Polk & Wardell', 'Federal Express Corporation', 9, 'SS', 'Acquiror', Decimal('20133.00')),
#  ('Parker & Parsley Petrolium Company', 'Baker & Botts', 'MESA, Inc.', 11, 'SS', 'Acquiror', Decimal('19800.00')),
#  ('Signet Banking Corp.', 'Credit Suisse First Boston', 'First Union Corporation', 6, 'SS', 'Acquiror', Decimal('19500.00')),
#  ('Quality Food Centers Inc.', 'Cleary, Gottlieb, Steen & Hamilton', 'Fred Meyer Inc.', 11, 'SS', 'Acquiror', Decimal('18700.00')),
#  ('Celebrity Cruise Lines Inc', 'Davis Polk & Wardell', 'Royal Caribbean Cruises Ltd.', 14, 'C/S', 'Acquiror', Decimal('18375.00')),
#  ('KU Energy Corporation', 'D.F. King & Co., Inc.', 'LG&E Energy Corporation', 12, 'SS', 'Acquiror', Decimal('18000.00')),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 'CIBC Wood Gundy Securities, Inc.', 'Coca-Cola Enterprises Inc.', 11, 'C/S', 'Acquiror', Decimal('17787.00')),
#  ('Chancellor Broadcasting Comp.', 'Jaffoni & Collins Inc.', 'Evergreen Media Corporation', 11, 'SS', 'Acquiror', Decimal('17600.00')),
#  ('Falcon Drilling Co.', 'Georgeson & Company Inc.', 'Reading & Bates Corporation', 7, 'SS', 'Acquiror', Decimal('17500.00')),
#  ('Valero Energy Corp.', 'Fulbright & Jaworski', 'PG&E Corporation', 11, 'SS', 'Acquiror', Decimal('16500.00')),
#  ('Amerisource Health Corp.', 'Fried, Frank, Harris, Shriver & Jacobson', 'McKesson Corp.', 7, 'SS', 'Acquiror', Decimal('16254.00')),
#  ('T&N PLC', 'Cazenove', 'Federal-Mogul Corp.', 7, 'C/S', 'Acquiror', Decimal('16100.00')),
#  ('AT&T Capital Corp.', 'Simpson Thacher & Bartlett', 'AT&T Capital Corp.', 10, 'C/S', 'Target', Decimal('16000.00')),
#  ('Equitable of Iowa Companies', 'Salomon Brothers Inc.', 'ING Group NV', 6, 'C/S', 'Acquiror', Decimal('15600.00')),
#  ('Pacificorp', 'Boles & Boles', 'Century Telephone Enterprises Inc.', 7, 'C/S', 'Acquiror', Decimal('15561.00')),
#  ('Nellcor Puritan Bennett Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Mallinckrodt Inc.', 8, 'TO', 'Acquiror', Decimal('15200.00')),
#  ('The Dow Chemical Company', 'Credit Suisse First Boston', 'S.C. Johnson & Son Inc.', 10, 'C/S', 'Acquiror', Decimal('15000.00')),
#  ('Brooks Fiber Properties, Inc.', 'Peper, Martin, Jensen, Maichel and Hetlage', 'WorldCom, Inc.', 5, 'SS', 'Acquiror', Decimal('14500.00')),
#  ('Allied Colloids Group PLC', 'Sullivan & Cromwell', 'Allied Colloids Group', 8, 'C/S', 'Target', Decimal('14480.00')),
#  ('Octel Communications Corporation', 'Morrow & Co., Inc.', 'Lucent Technologies Inc.', 8, 'TO', 'Acquiror', Decimal('14400.00')),
#  ('The Multicare Companies, Inc.', 'Cleary, Gottlieb, Steen & Hamilton', 'Genesis ElderCare Corp., Cypress Group & TX Pacifi', 10, 'TO', 'Acquiror', Decimal('13920.00')),
#  ('Central Fidelity Banks Inc.', 'Credit Suisse First Boston', 'Wachovia Corporation', 6, 'SS', 'Acquiror', Decimal('13800.00')),
#  ('Healthsource, Inc.', 'Georgeson & Company Inc.', 'CIGNA Corporation', 8, 'TO', 'Acquiror', Decimal('13600.00')),
#  ('Stone-Consolidated Corp.', 'Credit Suisse First Boston', 'Abitibi-Price Inc.', 9, 'C/S', 'Acquiror', Decimal('13500.00')),
#  ('Amphenol Corp.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'Kohlberg Kravis Roberts & Co.', 9, 'CM', 'Acquiror', Decimal('13500.00')),
#  ('Cowles Media Company', 'Cleary, Gottlieb, Steen & Hamilton', 'McClatchy Newspapers, Inc.', 9, 'C/S', 'Acquiror', Decimal('13410.00')),
#  ('Horizon/CMS Healthcare Corp.', 'Dewey Ballantine', 'HealthSouth Corp.', 8, 'SS', 'Acquiror', Decimal('13200.00')),
#  ('Santa Fe Pacific Pipeline Partners', 'Akin, Gump, Strauss, Hauer & Feld', 'Kinder Morgan Energy Partners', 12, 'C/S', 'Acquiror', Decimal('13200.00')),
#  ('American First Financial Insurance Group Inc.', 'Dewey Ballantine', 'American Bankers Insurance Group Inc.', 6, 'C/S', 'Target', Decimal('13200.00')),
#  ('Living Centers of America Inc.', 'in-house', 'Apollo Management L.P.', 13, 'SS', 'Merger Partner', Decimal('13000.00')),
#  ('Sony Corporation of America', 'Goodman and Carr', 'Cineplex Odeon Corp.', 13, 'SS', 'Merger Partner', Decimal('13000.00')),
#  ('Vivra Inc.', 'Citigate Inc.', 'Incentive AB', 8, 'TO', 'Acquiror', Decimal('12720.00')),
#  ('Homeside, Inc.', 'Cohane Rafferty Securities Inc.', 'National Bank Australia Limited', 10, 'CM', 'Acquiror', Decimal('12300.00')),
#  ('SFX Broadcasting Inc.', 'Kekst and Company', 'Hicks, Muse, Tate & Furst Inc.', 10, 'C/S', 'Acquiror', Decimal('12000.00')),
#  ('Imperial Chemical Industries PLC', 'BT Wolfensohn', 'DuPont Co.', 4, 'C/S', 'Acquiror', Decimal('12000.00')),
#  ('United Waste Systems, Inc.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'USA Waste Services Inc.', 8, 'SS', 'Acquiror', Decimal('12000.00')),
#  ('Viacom Inc.', 'Goldman, Sachs & Co.', 'Seagram Co.', 7, 'C/S', 'Acquiror', Decimal('11900.00')),
#  ('Alex. Brown Inc.', 'BT Wolfensohn', 'Bankers Trust New York Corporation', 7, 'SS', 'Acquiror', Decimal('11900.00')),
#  ('Advanta Corp.', 'Kekst and Company', 'Fleet Financial Group, Inc.', 9, 'C/S', 'Acquiror', Decimal('11700.00')),
#  ('Showboat Inc.', 'Weil, Gotshal & Manges', 'Showboat Inc.', 9, 'C/S', 'Target', Decimal('11547.00')),
#  ('The Dow Chemical Company', 'Chadbourne & Parke', 'NGC Corp.', 9, 'TO', 'Acquiror', Decimal('11430.00')),
#  ('Powernet Victoria', 'J.P. Morgan & Co., Inc.', 'GPU, Inc.', 6, 'PA', 'Acquiror', Decimal('11280.00')),
#  ('The Quick & Reilly Group, Inc.', 'Cleary, Gottlieb, Steen & Hamilton', 'Fleet Financial Group, Inc.', 7, 'SS', 'Acquiror', Decimal('11200.00')),
#  ('Retail Property Trust', "O'Melveny & Myers", 'Retail Property Trust', 11, 'C/S', 'Target', Decimal('11000.00')),
#  ('Heritage Media Corp.', 'Merrill Lynch & Co.', 'The News Corporation Limited', 8, 'C/S', 'Acquiror', Decimal('10840.00')),
#  ('Western National Corp.', 'Debevoise & Plimpton', 'American General Corp.', 9, 'C/S', 'Acquiror', Decimal('10800.00')),
#  ('Keystone International Inc.', 'Kekst and Company', 'Tyco International Ltd.', 9, 'SS', 'Acquiror', Decimal('10800.00')),
#  ('Johnson & Higgins', 'J.P. Morgan & Co., Inc.', 'Marsh & McLennan Companies, Inc.', 6, 'C/S', 'Acquiror', Decimal('10800.00')),
#  ('Westin Hotels & Resorts', 'Fried, Frank, Harris, Shriver & Jacobson', 'Starwood Lodging Trust', 6, 'C/S', 'Acquiror', Decimal('10680.00')),
#  ('Uslife Corp.', 'Skadden, Arps, Slate, Meagher & Flom', 'American General Corp.', 6, 'SS', 'Acquiror', Decimal('10620.00')),
#  ('Tencor Instruments Inc.', 'Merrill Lynch & Co.', 'KLA Instruments Corporation', 8, 'SS', 'Acquiror', Decimal('10400.00')),
#  ('Westinghouse Electric Corp.', 'Merrill Lynch & Co.', 'Ingersoll-Rand Company', 4, 'C/S', 'Acquiror', Decimal('10240.00')),
#  ('Apria Healthcare Group Inc.', 'Cravath, Swaine & Moore', 'Investor Group led by Transworld Healthcare Inc.', 7, 'C/S', 'Acquiror', Decimal('10150.00')),
#  ('Scudder, Stevens & Clark Inc.', 'Lazard Freres & Co. LLC', 'Zurich Group', 6, 'C/S', 'Acquiror', Decimal('10002.00')),
#  ('Doubletree Corporation', 'BT Wolfensohn', 'Promus Hotel Corp.', 5, 'SS', 'Acquiror', Decimal('10000.00')),
#  ('Target Therapeutics, Inc.', 'Lehman Brothers', 'Boston Scientific Corporation', 9, 'SS', 'Acquiror', Decimal('9900.00')),
#  ('Renal Treatment Centers Inc.', 'Cravath, Swaine & Moore', 'Renal Treatment Centers Inc.', 9, 'SS', 'Target', Decimal('9900.00')),
#  ('Cigna Corporation', 'Merrill Lynch & Co.', 'Lincoln National Corporation', 7, 'C/S', 'Acquiror', Decimal('9800.00')),
#  ('Telco Communications Group Inc.', 'Lehman Brothers', 'Excel Communications, Inc.', 9, 'C/S', 'Acquiror', Decimal('9720.00')),
#  ('Viacom Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Evergreen Media Corporation', 9, 'C/S', 'Acquiror', Decimal('9675.00')),
#  ('H&R Block Inc.', 'Bryan Cave', 'WorldCom, Inc.', 8, 'C/S', 'Acquiror', Decimal('9600.00')),
#  ('Chauvco Resources LTD.', 'Goldman, Sachs & Co.', 'Pioneer Natural Resources Co.', 8, 'C/S', 'Acquiror', Decimal('9576.00')),
#  ('Verifone, Inc.', 'Drinker Biddle & Reath', 'Hewlett-Packard Company', 8, 'SS', 'Acquiror', Decimal('9440.00')),
#  ('Westinghouse Electric Corp.', 'Goldman, Sachs & Co.', 'Siemens A.G.', 6, 'C/S', 'Acquiror', Decimal('9150.00')),
#  ('First Commerce Corp.', 'Wachtell, Lipton, Rosen & Katz', 'Banc One Corporation', 3, 'SS', 'Acquiror', Decimal('9000.00')),
#  ('Wyndham Hotel Corp.', 'Goodwin, Procter & Hoar', 'Patriot American Hospitality Inc.', 8, 'C/S', 'Acquiror', Decimal('8800.00')),
#  ('Hercules Inc. and Mallickrodt Inc', 'Davis Polk & Wardell', 'Roche Holding AG', 8, 'C/S', 'Acquiror', Decimal('8800.00')),
#  ('Monterey Resources Inc.', 'Credit Suisse First Boston', 'Texaco Inc.', 8, 'SS', 'Acquiror', Decimal('8800.00')),
#  ('Universal Outdoor Holdings Inc.', 'Akin, Gump, Strauss, Hauer & Feld', 'Clear Channel Communications, Inc.', 5, 'SS', 'Acquiror', Decimal('8750.00')),
#  ('Fisher Scientific International Inc.', 'Davis Polk & Wardell', 'Inv. Group led by Thomas H. Lee Company', 8, 'C/S', 'Acquiror', Decimal('8480.00')),
#  ('Starwood Lodging Corp.', 'Kirkland & Ellis', 'ITT World Directories', 4, 'C/S', 'Target', Decimal('8400.00')),
#  ('United Meridian Corp.', 'Akin, Gump, Strauss, Hauer & Feld', 'United Meridian Corp.', 7, 'SS', 'Merger Partner', Decimal('8400.00')),
#  ('Dauphin Deposit Corp.', 'Merrill Lynch & Co.', 'Allied Irish Banks P.L.C.', 6, 'C/S', 'Acquiror', Decimal('8160.00')),
#  ('Sodexho Alliance S.A.', 'Davis Polk & Wardell', 'Sodexho Alliance S.A.', 4, 'C/S', 'Target', Decimal('8000.00')),
#  ('Lucas Varity PLC', 'Freshfields', 'Perkins Engine unit', 6, 'C/S', 'Target', Decimal('7980.00')),
#  ('American Medical Response, Inc.', 'Katten Muchin & Zavis', 'Laidlaw Inc.', 7, 'C/S', 'Acquiror', Decimal('7840.00')),
#  ('Healthsouth Corp.', 'Blass & Driggs', 'Integrated Health Services Inc.', 6, 'C/S', 'Acquiror', Decimal('7500.00')),
#  ('Coulter Corp.', 'Sullivan & Cromwell', 'Coulter Corp.', 7, 'C/S', 'Target', Decimal('7350.00')),
#  ('Browning-Ferris Industries Inc.', 'Gavin Anderson & Company', 'SITA SA', 5, 'C/S', 'Acquiror', Decimal('7250.00')),
#  ('Greenfield Industries, Inc.', 'Buchanan Ingersol', 'Kennametal Inc.', 7, 'TO', 'Acquiror', Decimal('7000.00')),
#  ('Eller Media Corp.', 'Akin Gump', 'Clear Channel Communications, Inc.', 6, 'C/S', 'Acquiror', Decimal('6900.00')),
#  ('Transamerica Corp.', 'Morgan Stanley & Co. Inc.', 'Household International Inc.', 6, 'C/S', 'Acquiror', Decimal('6600.00')),
#  ('Value Health, Inc.', 'Fried, Frank, Harris, Shriver & Jacobson', 'Columbia-HCA Healthcare Corporation', 5, 'SS', 'Acquiror', Decimal('6500.00')),
#  ('Ralston Purina Co.', 'Skadden, Arps, Slate, Meagher & Flom', 'DuPont Co.', 4, 'SS', 'Acquiror', Decimal('6000.00')),
#  ('BDM International', 'Willkie Farr & Gallagher', 'BDM International Inc.', 6, 'C/S', 'Target', Decimal('6000.00')),
#  ("Mac Frugal's Bargains & Close-Outs Inc.", 'Georgeson & Company Inc.', 'Consolidated Stores Corp.', 6, 'SS', 'Acquiror', Decimal('6000.00')),
#  ('Cifra S.A.', 'Banamex', 'Cifra S.A.', 5, 'C/S', 'Target', Decimal('6000.00')),
#  ('Zilkha Energy Co.', 'Andrews & Kurth', 'Zilkha Energy Co.', 5, 'C/S', 'Target', Decimal('5200.00')),
#  ('Network General Corp.', 'Morgan Stanley Dean Witter', 'McAfee Associates Inc.', 4, 'SS', 'Acquiror', Decimal('5200.00')),
#  ('Laidlaw Inc.', 'Katten Muchin & Zavis', 'Laidlaw Environmental Services, Inc. & Laidlaw Env', 4, 'SS', 'Target', Decimal('4920.00')),
#  ('Montgomery Securities', 'Credit Suisse First Boston', 'NationsBank Corporation', 4, 'C/S', 'Acquiror', Decimal('4800.00')),
#  ('Evans Withycombe Residential Inc.', 'J.P. Morgan & Co., Inc.', 'Equity Residential Properties Trust', 4, 'C/S', 'Acquiror', Decimal('4228.00')),
#  ('First Financial Corp.', 'Shearman & Sterling', 'Associated Banc-Corp', 4, 'SS', 'Acquiror', Decimal('4200.00')),
#  ('Minnesota Mining and Manufacturing Comp.', 'CIBC Wood Gundy Inc.', 'Outdoor Systems Inc.', 4, 'C/S', 'Acquiror', Decimal('4000.00')),
#  ('Berliner Kraft & Licht AG', 'Dresdner Kleinwort Benson', 'Inv. Group led by Southern Comp. and Viag AG', 2, 'C/S', 'Acquiror', Decimal('3740.00')),
#  ('Bankamerica Corp.', 'Bear, Stearns & Co., Inc.', 'Security Pacific Financial Services', 2, 'C/S', 'Target', Decimal('3200.00')),
#  ('Hermann Healthcare System', 'Andrews & Kurth', 'Hermann Healthcare System', 2, 'C/S', 'Target', Decimal('2000.00'))]
